# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushintha18/AI-Pest-Detection/blob/main/ai_pest_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.3 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 68.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="lL56ENgbETMdUDoZ6lw2")  # Replace with your API key
project = rf.workspace("sushinthas-workspace").project("crop-disease-srixo-0iros")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crop-disease-1 in yolov8:: 100%|██████████| 6878/6878 [00:00<00:00, 7495.85it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/crop-disease-1/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
model.train(
    data="/content/crop-disease-1/data.yaml",
    epochs=10,
    imgsz=416
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-438/1464274151.py in <cell line: 0>()
# ----> 1 model.train(
#       2     data="/content/crop-disease-1/data.yaml",
#       3     epochs=10,
#       4     imgsz=416
#       5 )
#
# NameError: name 'model' is not defined

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(
    data="/content/crop-disease-1/data.yaml",
    epochs=10,
    imgsz=416
)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lL56ENgbETMdUDoZ6lw2")
project = rf.workspace("sushinthas-workspace").project("crop-disease-srixo-0iros")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crop-disease-1 in yolov8:: 100%|██████████| 6878/6878 [00:00<00:00, 7975.11it/s]

# %%
# !ls /content
# Out:
# crop-disease-1	runs  sample_data  yolov8n.pt

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/crop-disease-1/data.yaml",
    epochs=10,
    imgsz=416
)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61bb0f4c-3718-44a6-bb46-65fff6bb504b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61bb0f4c-3718-44a6-bb46-65fff6bb504b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
from google.colab import files
import cv2
from google.colab.patches import cv2_imshow

# 1. Load the model you just trained
# Note: Your output showed 'train2', so we use that path
model = YOLO('/content/runs/detect/train2/weights/best.pt')

# 2. Upload the image
print("Select your crop disease image:")
uploaded = files.upload()

for filename in uploaded.keys():
    # 3. Run prediction
    # 'conf=0.25' means only show detections the AI is 25% sure about
    results = model.predict(source=filename, conf=0.25, save=True)

    # 4. Display the result directly in Colab
    res_plotted = results[0].plot()
    cv2_imshow(res_plotted)
# Out:
# Select your crop disease image:
#      <input type="file" id="files-2b5eefbe-ca1c-47f9-8833-89a9cf1ddf78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b5eefbe-ca1c-47f9-8833-89a9cf1ddf78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from google.colab import files
uploaded = files.upload()
video_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-eac56049-287c-4996-af30-e5e0485b336a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eac56049-287c-4996-af30-e5e0485b336a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load your best trained model
model = YOLO("/content/runs/detect/train2/weights/best.pt")

# Run prediction on the video
# 'conf=0.25' ignores weak detections
# 'save=True' saves the result video
results = model.predict(source=video_path, conf=0.25, save=True)

print("Detection complete! Check the output folder.")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/246) /content/pest_video2.mp4: 256x416 (no detections), 56.9ms
# video 1/1 (frame 2/246) /content/pest_video2.mp4: 256x416 (no detections), 9.2ms
# video 1/1 (frame 3/246) /content/pest_video2.mp4: 256x416 (no detections), 9.3ms
# video 1/1 (frame 4/246) /content/pest_video2.mp4: 256x416 (no detections), 13.1ms
# video 1/1 (frame 5/246) /content/pest_video2.mp4: 256x416 (no detections), 11.1ms
# ...

# %%
from google.colab import files
uploaded = files.upload()
video_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-03e178f4-697b-4d2a-aa64-2a7e42ddacfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03e178f4-697b-4d2a-aa64-2a7e42ddacfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load your best trained model
model = YOLO("/content/runs/detect/train2/weights/best.pt")
results = model.predict(source=video_path, conf=0.25, save=True)

print("Detection complete! Check the output folder.")
